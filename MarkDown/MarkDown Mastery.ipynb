# %% [markdown]
# # Jupyter notebook Markdown lesson

# %% [markdown]
# 1. <a href="#1--Alert-Boxs">Alert Boxs
# 2. <a href="#2--Backquotes">Backquotes
# 3. <a href="#3--Matematical-Expressions">Matematical Expressions
# 4. <a href="#4--Line-Breaks">Line Breaks
# 5. <a href="#5--Bold-And-Italic-Text">Bold And Italic Text
# 6. <a href="#6--Horizontal-Lines">Horizontal Lines
# 7. <a href="#7--Ordered-List">Ordered List
# 8. <a href="#8--Unordered-List">Unordered List
# 9. <a href="#9--Internal-and-External-Links">Internal and External Links

# %% [markdown]
# ## 1- Alert Boxs

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes. These should only be
# used for actions that might cause data loss or another major issue.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %%
# 3- Matematical Expressions

# %% [markdown]
# ## 2- Backquotes

# %% [markdown]
# Hi My Friend
# > I am Backquotes

# %% [markdown]
# ## 3- Matematical Expressions
#
# $\sum$
#
# https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214

# %% [markdown]
# ## 4- Line Breaks

# %% [markdown]
# This is  <br> how you break things

# %% [markdown]
# ## 5- Bold And Italic Text

# %% [markdown]
# **Jupyter Notebook Bold Text**  <br>
# __Jupyter Notebook Bold Text__ <br>
# *Python Italic Text*  <br>
# _Python Italic Text_  <br>

# %% [markdown]
# ## 6- Horizontal Lines

# %% [markdown]
# ---
# Lol Horizontal Lines
#
#
# ---

# %% [markdown]
# ## 7- Ordered List

# %% [markdown]
# 1. Python
# 2. Java
# 3. Julia
#
# <ol>
#     <li>Python</li>
#     <li>Java</li>
#     <li>Julia</li>

# %% [markdown]
# ## 8- Unordered List

# %% [markdown]
# - Java
# - Python
# - Julia
#
# <ul>
#     <li>Java
#     <li>Warcraft
#     <li>Dotka

# %% [markdown]
# ## 9- Internal and External Links

# %% [markdown]
# ---
# <a href="#Jupyter-notebook-Markdown-lesson">Internal Example Place
#
# ---

# %% [markdown]
# ---
# <a href="https://github.com/Munkun">My Github
#
# ---

# %% [markdown]
# ## 10- Image

# %% [markdown]
# ![1195265.jpg](attachment:1195265.jpg)

# %% [markdown]
# Go Edit and Click Insert Image Jupyter notebook will do his work

# %% [markdown]
# ## 11- Video

# %% [markdown]
# ## <video controls src="Tengen%20Uzui%20vs%20Gyutaro%20fight%20%284k%29.mp4" width=960 height=540/>
